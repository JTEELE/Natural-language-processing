# %%
#Use this to extract specific information via Web Scraping.
#Not reliable to NLP purposes because scraped data contains lots of web traffic & advertisements. 
import sys, os
import glob
cwd = os.getcwd()
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer 
from collections import Counter
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import reuters, stopwords
import re
import nltk
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['AMZN', 'GOOG', 'TSLA']
news_tables = {}
for ticker in tickers:
    url = finviz_url + ticker
    req = Request(url=url, headers={'user-agent': 'my-app'})
    response = urlopen(req)
    html = BeautifulSoup(response, features='html.parser')
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table

parsed_data = []
url_dict = {}
for ticker, news_table in news_tables.items():
    url_ls = []
    for row in news_table.findAll('tr'):

        if row.a is None:
            pass
        else:
            title = row.a.text
            date_data = row.td.text.split(' ')
            url_extraction = str(row)
            string_search = re.search('https(.+?)"', url_extraction)
            if string_search:
                extracted_url = string_search.group(1)
                final_url = 'http' + extracted_url
                url_ls.append(final_url)


        if len(date_data) == 1:
            time = date_data[0]
        else:
            date = date_data[0]
            time = date_data[1]

        parsed_data.append([ticker, date, time, title])

    ticker_url_list = pd.DataFrame(url_ls, columns = [ticker])
    url_dict[ticker] = ticker_url_list
df = pd.DataFrame(parsed_data, columns=['ticker', 'date', 'time', 'title'])

vader = SentimentIntensityAnalyzer()

f = lambda title: vader.polarity_scores(title)['compound']
df['compound'] = df['title'].apply(f)
df['date'] = pd.to_datetime(df.date).dt.date

# %%
item='AMZN'
testing = url_dict['AMZN']
list = testing[item].tolist()
for item in list:
    print(list)
# Out:
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...
# ['http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011542610.html', 'http://finance.yahoo.com/news/u-begins-antitrust-review-amazon-011104249.html', 'http://www.wsj.com/articles/ftc-investigating-amazon-deal-to-buy-one-medical-network-of-health-clinics-11662157363?siteid=yhoof2', 'http://finance.yahoo.com/news/amazon-amzn-stock-moves-0-214509401.html', 'http://www.barrons.com/articles/dan-niles-satori-fund-gambling-apple-stocks-51662069936?siteid=yhoof2', 'http://finance.yahoo.com/news/u-ftc-asks-amazon-one-211317136.html', 'http://www.fool.com/investing/2022/09/02/why-plug-power-shares-plunged-40-on-friday/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/video/rings-power-viewers-report-issues-201822535.html', 'http://finance.yahoo.com/news/amazon-closes-abandons-plans-dozens-155259786.html', 'http://www.fool.com/investing/2022/09/02/why-cheetah-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/why-cheetah-mobile-stock-soared-friday-morning/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2', 'http://finance.yahoo.com/video/microsoft-confirms-xbox-game-pass-155531277.html', 'http://finance.yahoo.com/video/amazon-labor-union-president-going-155105337.html', 'http://finance.yahoo.com/news/broadcom-gives-strong-forecast-evading-202439177.html', 'http://finance.yahoo.com/news/chinas-e-commerce-giant-pinduoduo-144549815.html', 'http://finance.yahoo.com/video/nlrb-upholds-amazon-union-vote-143345091.html', 'http://finance.yahoo.com/news/15-most-valuable-indian-tech-142158793.html', 'http://finance.yahoo.com/news/amazon-amzn-unveils-supply-chain-140302378.html', 'http://www.fool.com/investing/2022/09/02/up-10-after-the-stock-split-is-amazon-stock-still/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/1-amazon-staff-uk-warehouse-124927747.html', 'http://www.fool.com/investing/2022/09/02/why-signify-health-jumped-63-in-august/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/fires-electrical-explosions-erupted-amazons-115900421.html', 'http://finance.yahoo.com/news/amazon-overruled-in-labor-case-staten-island-union-vote-115612295.html', 'http://www.fool.com/investing/2022/09/02/2-top-dividend-stocks-2023-social-security-cola/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/amazon-workers-unionization-gains-momentum-113605741.html', 'http://finance.yahoo.com/news/amazon-walmart-want-faa-let-105800750.html', 'http://www.fool.com/investing/2022/09/02/1-growth-stock-thats-played-out-and-1-thats-just-s/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://finance.yahoo.com/news/us-deals-heavy-blow-china-100727058.html', 'http://www.fool.com/investing/2022/09/02/amazon-microsoft-alphabet-partnered-ai-stock-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.fool.com/investing/2022/09/02/2-ultra-growth-stocks-leading-market-recovery/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/streaming-amazon-lord-of-the-rings-netflix-disney-11662064745?siteid=yhoof2', 'http://www.fool.com/investing/2022/09/02/3-warren-buffett-stocks-to-buy-in-september/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article', 'http://www.wsj.com/articles/labor-official-recommends-amazon-union-victory-in-new-york-be-upheld-11662070631?siteid=y ...

# %%
top_record_count=20
string_ls = []
for item in url_dict:
    url_df = (url_dict[item])
    ticker_url_list = url_df[item].tolist()
    for url in ticker_url_list:
        req = Request(url=url, headers={'user-agent': 'my-app'})
        response = urlopen(req)
        html = BeautifulSoup(response, features='html.parser')
        raw_text = html.get_text()
        lines = (line.strip() for line in raw_text.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        text = '\n'.join(chunk for chunk in chunks if chunk)
        string_ls.append(text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\JakeTeele\Documents\GitHub\Natural-language-processing\fin_viz_webscraping.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> for url in ticker_url_list:
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     req = Request(url=url, headers={'user-agent': 'my-app'})
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     response = urlopen(req)
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     html = BeautifulSoup(response, features='html.parser')
#      <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>     raw_text = html.get_text()
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:555, in OpenerDirector.error(self, proto, *args)
#     553     http_err = 0
#     554 args = (dict, proto, meth_name) + args
# --> 555 result = self._call_chain(*args)
#     556 if result:
#     557     return result
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:747, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     744 fp.read()
#     745 fp.close()
# --> 747 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
sample_url = str(text)
strip_lines=sample_url.strip()
lemmatizer = WordNetLemmatizer()
stop_words_list = set(stopwords.words('english'))
# stop_words_list = list(nltk_stop_words)
include_in_stopwords = ['ha']
remove_from_stopwords = ['all', 'below', 'being', 'too']
stop_words = [elem for elem in stop_words_list if elem not in remove_from_stopwords]
stop_words = stop_words+include_in_stopwords
regex = re.compile("[^a-zA-Z ]")
re_clean = regex.sub('', strip_lines)
words = word_tokenize(re_clean)
lem = [lemmatizer.lemmatize(word) for word in words]
output = [c for c in lem if c.islower()]
output = [word.lower() for word in output if word.lower() not in stop_words]
top_10 = dict(Counter(output).most_common(top_record_count))
# top_10_df = pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
type(text)
# Out:
# str

# %%
url
# Out:
# 'http://www.wsj.com/articles/law-firms-jockey-to-help-companies-manage-diversity-and-equity-11662136442?siteid=yhoof2'

# %%
html = BeautifulSoup(response, features='html.parser')
text = html.get_text()
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# c:\Users\JakeTeele\Documents\GitHub\Natural-language-processing\fin_viz_webscraping.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> html = BeautifulSoup(response, features='html.parser')
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/fin_viz_webscraping.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> text = html.get_text()
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\site-packages\bs4\__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\http\client.py:476, in HTTPResponse.read(self, amt)
#     474 else:
#     475     try:
# --> 476         s = self._safe_read(self.length)
#     477     except IncompleteRead:
#     478         self._close_conn()
#
# File c:\Users\JakeTeele\anaconda3\envs\ml\lib\http\client.py:628, in HTTPResponse._safe_read(self, amt)
#     626 chunk = self.fp.read(min(amt, MAXAMOUNT))
#     627 if not chunk:
# --> 628     raise IncompleteRead(b''.join(s), amt)
#     629 s.append(chunk)
#     630 amt -= len(chunk)
#
# IncompleteRead: IncompleteRead(125587 bytes read, 387175 more expected)

# %%
lines = (line.strip() for line in raw_text.splitlines())
text = '.'.split(lines)
text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\JakeTeele\Documents\GitHub\Natural-language-processing\finviz_nlp_v3.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/finviz_nlp_v3.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> lines = (line.strip() for line in raw_text.splitlines())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/finviz_nlp_v3.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> text = '.'.split(lines)
#       <a href='vscode-notebook-cell:/c%3A/Users/JakeTeele/Documents/GitHub/Natural-language-processing/finviz_nlp_v3.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> text
#
# TypeError: must be str or None, not generator

# %%
lines
# Out:
# <generator object <genexpr> at 0x000002D928E4B120>
